# %%
# %matplotlib inline
import pyedflib
from scipy import *
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
import traceback
from scipy.io import savemat, loadmat
plt.figure(1, figsize = (8.5,11))

data = loadmat("/Users/smitra/projects/webChronux/matspectrogram.mat")["S"]
np.shape(data)
# Out:
# (15806, 820)

# %%
plt.figure(1, figsize = (8.5,11))
plt.suptitle('Spectrogram')
ax = []
aPlot = plt.subplot(321, axisbg = 'w', title = "Year 1")
ax.append(aPlot)
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.imshow(np.array(data).transpose())
